# %% [markdown]
# ### Initialize

# %%
import os
import random

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from adjustText import adjust_text
from scipy.sparse import coo_matrix
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc
from torch.utils.data import Dataset, DataLoader

random.seed(42)
torch.manual_seed(42)
torch.mps.manual_seed(42)

# %%
chr_index = pd.read_csv("index.csv", header=0)
pos_coord_egfr = np.where(chr_index["loc"] == "chr7_55000000")[0][0]
pos_coord_myc = np.where(chr_index["loc"] == "chr8_127000000")[0][0]

window_0 = 5
window_1 = 5

# %%
def read_mtx(path, index):
    contact_mat = pd.read_csv(path, sep="\t", header=0)
    contact_mat = contact_mat[(contact_mat["chrom1"] != "chrY") & (contact_mat["chrom2"] != "chrY")]
    contact_mat = pd.concat([contact_mat["chrom1"] + "_" + contact_mat["start1"].astype(str),
                             contact_mat["chrom2"] + "_" + contact_mat["start2"].astype(str), contact_mat["count"]],
                            axis=1)
    contact_mat.columns = ["loc1", "loc2", "count"]
    contact_mat = pd.merge(contact_mat, index, left_on="loc1", right_on="loc", how="left").drop(["loc", "loc1"], axis=1)
    contact_mat = contact_mat.rename(columns={contact_mat.columns[2]: "index1"})
    contact_mat = pd.merge(contact_mat, index, left_on="loc2", right_on="loc", how="left").drop(["loc", "loc2"], axis=1)
    contact_mat = contact_mat.rename(columns={contact_mat.columns[2]: "index2"})
    contact_mat = coo_matrix((contact_mat['count'], (contact_mat['index1'], contact_mat['index2'])),
                             shape=(index.shape[0], index.shape[0]))
    contact_mat = contact_mat.toarray()

    return contact_mat

# %%
def read_add(path, index):
    add = pd.read_csv(path, sep="\t", header=None)
    add.columns = ["chrom", "start", "end", "add"]
    add = add[add["chrom"] != "chrY"]
    add = pd.concat([add["chrom"] + "_" + add["start"].astype(str), add["add"]],axis=1)
    add.columns = ["loc", "add"]
    add = pd.merge(add, index, on="loc", how="left")

    return add

# %%
def prep_data(sample, coord, index, is_pos, win0):
    matrices = []
    adds = []
    bcs = []

    directories = sorted([d for d in os.listdir("data/raw/" + sample) if os.path.isdir(os.path.join("data/raw/" + sample, d))])
    for directory in directories:
            
        try:
            add = read_add("data/raw/" + sample + "/" + directory + "/1000000.CNV.bedGraph", index)
        except:
            continue

        try:
            mtx = read_mtx("data/raw/" + sample + "/" + directory + "/matrix.mtx", index)
        except:
            continue
            
        if len(add) != mtx.shape[0]:
            continue
            
        mtx = torch.from_numpy(mtx[(coord - int((win0 + 1) / 2) + 1):(coord + int((win0 + 1) / 2)), :]).to_sparse_coo()
        add = torch.from_numpy(add[(coord - int((win0 + 1) / 2) + 1):(coord + int((win0 + 1) / 2))]["add"].to_numpy(dtype=np.float32))

        matrices.append(mtx)
        adds.append(add)
        
        bcs = bcs + [directory]

    input = torch.stack(matrices, dim=0)
    adds = torch.stack(adds, dim=0)

    if is_pos:
        label = torch.from_numpy(np.ones(input.shape[0])).int()
    else:
        label = torch.from_numpy(np.zeros(input.shape[0])).int()

    return input, label, bcs, adds

# %% [markdown]
# ### Prepare data

# %%
orig_index = pd.read_csv("data/raw/LC675/LC675_TTTGGTTGTTGGCGAA/1000000.CNV.bedGraph", sep="\t", header=None).iloc[:, 0:3]

orig_index.columns = ["chrom", "start", "end"]
orig_index = orig_index[orig_index["chrom"] != "chrY"]
orig_index = orig_index["chrom"] + "_" + orig_index["start"].astype(str)
orig_index = pd.concat([orig_index, pd.DataFrame(np.arange(orig_index.shape[0]))], axis=1)
orig_index.columns = ["loc", "index"]

orig_index.to_csv("index.csv", index=False)

# %%
pos_data, pos_label, pos_bcs, pos_add = prep_data("LC499", pos_coord_egfr, chr_index, True, window_0)
neg_data, neg_label, neg_bcs, neg_add = prep_data("LC500", pos_coord_egfr, chr_index, False, window_0)

input_all = torch.cat((pos_data, neg_data), dim=0).unsqueeze(1)
label = torch.cat((pos_label, neg_label), dim=0)
barcode = pos_bcs + neg_bcs
add = torch.cat((pos_add, neg_add), dim=0)

# %%
#torch.save(input_all, "data/processed/input_499500.npy")
#torch.save(label, "data/processed/label_499500.npy")
#torch.save(barcode, "data/processed/barcodes_499500.npy")
torch.save(add, "data/processed/add_499500.npy")

# %%
val_split = 0.1

len_indices = len(input_all)
all_indices = list(range(len_indices))
random.shuffle(all_indices)
num_val = int(np.floor(val_split * len_indices))

val_indices = torch.tensor(all_indices[:num_val])
train_indices = torch.tensor(all_indices[num_val:])

input_train = torch.index_select(input_all, 0, train_indices)
label_train = torch.index_select(label, 0, train_indices)
bcs_train = [barcode[i] for i in train_indices]

input_val = torch.index_select(input_all, 0, val_indices)
label_val = torch.index_select(label, 0, val_indices)
bcs_val = [barcode[i] for i in val_indices]

pd.DataFrame(bcs_val).to_csv("data/processed/barcode_val_499500.txt", index=False,header=False)

# %%
pos_data, pos_label, pos_bcs, pos_add = prep_data("LC729", pos_coord_myc, chr_index, True, window_0)
neg_data, neg_label, neg_bcs, neg_add = prep_data("LC730", pos_coord_myc, chr_index, False, window_0)

input_all = torch.cat((pos_data, neg_data), dim=0).unsqueeze(1)
label = torch.cat((pos_label, neg_label), dim=0)
barcode = pos_bcs + neg_bcs
add = torch.cat((pos_add, neg_add), dim=0)

# %%
#torch.save(input_all, "data/processed/input_729730.npy")
#torch.save(label, "data/processed/label_729730.npy")
#torch.save(barcode, "data/processed/barcode_729730.npy")
torch.save(add, "data/processed/add_729730.npy")

# %%
pos_data, pos_label, pos_bcs, pos_add = prep_data("LC676", pos_coord_myc, chr_index, True, window_0)
neg_data, neg_label, neg_bcs, neg_add = prep_data("LC677", pos_coord_myc, chr_index, False, window_0)

input_all = torch.cat((pos_data, neg_data), dim=0).unsqueeze(1)
label = torch.cat((pos_label, neg_label), dim=0)
barcode = pos_bcs + neg_bcs
add = torch.cat((pos_add, neg_add), dim=0)

# %%
#torch.save(input_all, "data/processed/input_676677.npy")
#torch.save(label, "data/processed/label_676677.npy")
#torch.save(barcode, "data/processed/barcode_676677.npy")
torch.save(add, "data/processed/add_676677.npy")

# %%
val_split = 0.1

len_indices = len(input_all)
all_indices = list(range(len_indices))
random.shuffle(all_indices)
num_val = int(np.floor(val_split * len_indices))

val_indices = torch.tensor(all_indices[:num_val])
train_indices = torch.tensor(all_indices[num_val:])

input_train = torch.index_select(input_all, 0, train_indices)
label_train = torch.index_select(label, 0, train_indices)
bcs_train = [barcode[i] for i in train_indices]

input_val = torch.index_select(input_all, 0, val_indices)
label_val = torch.index_select(label, 0, val_indices)
bcs_val = [barcode[i] for i in val_indices]

pd.DataFrame(bcs_val).to_csv("data/processed/barcode_val_676677.txt", index=False,header=False)

# %% [markdown]
# ### Define model

# %%
input_499500 = torch.load("data/processed/input_499500.npy").to_dense()
label_499500 = torch.load("data/processed/label_499500.npy")
barcode_499500 = torch.load("data/processed/barcode_499500.npy")
add_499500 = torch.load("data/processed/add_499500.npy")

input_676677 = torch.load("data/processed/input_676677.npy").to_dense()
label_676677 = torch.load("data/processed/label_676677.npy")
barcode_676677 = torch.load("data/processed/barcode_676677.npy")
add_676677 = torch.load("data/processed/add_676677.npy")

input_729730 = torch.load("data/processed/input_729730.npy").to_dense()
label_729730 = torch.load("data/processed/label_729730.npy")
barcode_729730 = torch.load("data/processed/barcode_729730.npy")
add_729730 = torch.load("data/processed/add_729730.npy")

# %%
coordinate_499500 = np.repeat(pos_coord_egfr, input_499500.shape[0]).tolist()
coordinate_676677 = np.repeat(pos_coord_myc, input_676677.shape[0]).tolist()
coordinate_729730 = np.repeat(pos_coord_myc, input_729730.shape[0]).tolist()

# %%
input_all = input_499500
label = label_499500
barcode = barcode_499500# + barcode_676677
coordinate = coordinate_499500# + coordinate_676677
add = add_499500

#input_all = torch.cat((input_499500, input_676677), dim=0)
#label = torch.cat((label_499500, label_676677), dim=0)

# %%
validation_bcs_499500 = pd.read_table("data/processed/barcode_val_499500.txt",header=None).iloc[:,0].tolist()
#validation_bcs_676677 = pd.read_table("data/processed/barcode_val_676677.txt",header=None).iloc[:,0].tolist()
validation_bcs = validation_bcs_499500# + validation_bcs_676677

validation_indices = torch.tensor([i for i in range(len(barcode)) if barcode[i] in validation_bcs])
training_indices = torch.tensor([i for i in range(len(barcode)) if barcode[i] not in validation_bcs])

# %%
input_train = torch.index_select(input_all, 0, training_indices)
label_train = torch.index_select(label, 0, training_indices)
add_train = torch.index_select(add, 0, training_indices)
barcode_train = [barcode[i] for i in training_indices]
coordinate_train = [coordinate[i] for i in training_indices]

input_val = torch.index_select(input_all, 0, validation_indices)
label_val = torch.index_select(label, 0, validation_indices)
add_val = torch.index_select(add, 0, validation_indices)
barcode_val = [barcode[i] for i in validation_indices]
coordinate_val = [coordinate[i] for i in validation_indices]

# %%
class PentDataset(Dataset):
    def __init__(self, input, label, barcode, coord, add):
        self.input = input
        self.label = label
        self.barcode = barcode
        self.coord = coord
        self.add = add

    def __len__(self):
        return len(self.input)

    def __getitem__(self, index):
        input_s = self.input[index]
        label_s = self.label[index]
        bc_s = self.barcode[index]
        coord_s = self.coord[index]
        add_s = self.add[index]

        return input_s, label_s, bc_s, coord_s, add_s

# %%
batch_size = 32

train_dataloader = DataLoader(PentDataset(input_train, label_train, barcode_train, coordinate_train, add_train), batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(PentDataset(input_val, label_val, barcode_val, coordinate_val, add_val), batch_size=batch_size, shuffle=False)
test_dataloader1 = DataLoader(PentDataset(input_676677, label_676677, barcode_676677, coordinate_676677, add_676677), batch_size=batch_size, shuffle=False)
test_dataloader2 = DataLoader(PentDataset(input_729730, label_729730, barcode_729730, coordinate_729730, add_729730), batch_size=batch_size, shuffle=False)

# %%
def zi_pois_noise(shape, lambda_, p_zero):
    uniform_noise = torch.rand(shape)

    zero_mask = uniform_noise < p_zero

    poisson_noise = torch.poisson(lambda_ * torch.ones(shape))

    noise = poisson_noise * ~zero_mask

    return noise

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()

        self.conv_f2_l1 = nn.Conv2d(1, 8, kernel_size=(5, 45), stride=(1, 11), padding=(0, 2))
        self.conv_f2_l2 = nn.Conv2d(8, 16, kernel_size=(1, 45), stride=(1, 4), padding=(0, 0))
        
        self.bn_f2_l1 = nn.BatchNorm2d(8)
        self.bn_f2_l2 = nn.BatchNorm2d(16)
        
        self.bn_fc_l1 = nn.BatchNorm1d(64)

        self.pool_f2_l1 = nn.MaxPool2d(kernel_size=(1, 2), stride=2, padding=0)
        self.pool_f2_l2 = nn.MaxPool2d(kernel_size=(1, 2), stride=2, padding=0)
        
        self.fc_l1 = nn.Linear(5 * 5 + 12 * 16 + 5 + 5, 64)
        self.fc_l2 = nn.Linear(64, 1)

        #self.dropout_f1 = nn.Dropout(0.5)
        self.dropout_f2 = nn.Dropout(0.5)
        self.dropout_fc = nn.Dropout(0.5)

    def forward(self, x2, coord, add):
        #if self.training:
        #    noise = zi_pois_noise(x2.shape, 1, 0.9999)  # test this
        #    x2 = x2 + noise.float().to("mps")

        start_indices = coord - int((5 + 1) / 2) + 1
        end_indices = coord + int((5 + 1) / 2)

        d4_slices = []

        for i in range(x2.size(0)):
            d4_slices.append(x2[i, ..., start_indices[i]:end_indices[i]])

        x1 = torch.stack(d4_slices, dim=0)

        x1 = torch.log2(x1 + 1)
        x2 = (x2 > 0).float()
        
        add = torch.log2(add + 1)

        x2_s = F.normalize(torch.squeeze(torch.sum(x2, dim=-1), dim=1), dim=-1, p=1)

        x2 = self.pool_f2_l1(F.relu(self.bn_f2_l1(self.conv_f2_l1(x2))))
        x2 = self.dropout_f2(x2)
        x2 = self.pool_f2_l2(F.relu(self.bn_f2_l2(self.conv_f2_l2(x2))))
        
        x1 = x1.view(-1, 5 * 5)
        x2 = x2.view(-1, 12 * 16)
        
        x = torch.cat((x1, x2, x2_s, add), dim=1)

        x = self.dropout_fc(F.gelu(self.bn_fc_l1(self.fc_l1(x))))

        x = self.fc_l2(x)

        return x.squeeze(-1)

# %%
class BootBCELoss(nn.Module):
    def __init__(self, alpha, bootstrap_type, pos_weight):
        super(BootBCELoss, self).__init__()
        self.alpha = alpha
        self.bootstrap_type = bootstrap_type
        self.pos_weight = pos_weight

    def forward(self, prediction_tensor, target_tensor):
        if self.bootstrap_type == 'soft':
            bootstrap_target_tensor = self.alpha * target_tensor + (1.0 - self.alpha) * torch.sigmoid(prediction_tensor)
        elif self.bootstrap_type == 'hard':
            bootstrap_target_tensor = self.alpha * target_tensor + (1.0 - self.alpha) * (torch.sigmoid(prediction_tensor) > 0.5).float()
        else:
            raise ValueError('Not a valid value of bootstrap_type')
        
        per_entry_cross_ent = F.binary_cross_entropy_with_logits(input=prediction_tensor, target=bootstrap_target_tensor, reduction='mean',pos_weight=torch.Tensor([self.pos_weight]).to("mps"))

        return per_entry_cross_ent

# %%
model = CNN().to("mps")

prob_threshold = 0.5

# %%
criterion = BootBCELoss(alpha=0.8, bootstrap_type="hard", pos_weight=0.06).to("mps")

optimizer = optim.AdamW(model.parameters(), lr=0.0001)
#scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.5)
scheduler = optim.lr_scheduler.ConstantLR(optimizer, factor=0.1)

train_losses_epoch = []
val_losses_epoch = []

accuracies_epoch = []
precision_epoch = []
sensitivity_epoch = []
specificity_epoch = []
f1_epoch = []

epochs = []

num_epochs = 80

# %% [markdown]
# ### Train model

# %%
for epoch in range(num_epochs):
    
    if epoch >= 60:
        scheduler.step()
    
    losses = []
    sizes = []

    model.train()
    for x2, y0, _, coord, add in train_dataloader:
        x2 = x2.float().to("mps")
        y0 = y0.float().to("mps")
        add = add.float().to("mps")

        optimizer.zero_grad()
        yh = model(x2, coord, add)
        
        loss = criterion(yh, y0)
        loss.backward()
        optimizer.step()

        losses.append(loss.item())
        sizes.append(len(y0))

    train_loss = np.average(losses, weights=sizes)

    losses = []
    sizes = []

    val_labels = []
    val_predictions = []
    val_scores = []
    val_directories = []

    model.eval()
    with torch.no_grad():
        for x2, y0, bcs, coord, add in val_dataloader:
            x2 = x2.float().to("mps")
            y0 = y0.float().to("mps")
            add = add.float().to("mps")

            yh = model(x2, coord, add)
            
            loss = criterion(yh, y0)

            yp = (torch.sigmoid(yh) > prob_threshold).int()

            accu = torch.sum((yp == y0).float()) / len(y0)

            losses.append(loss.item())
            sizes.append(len(y0))

            val_labels = val_labels + y0.int().to("cpu").numpy().tolist()
            val_predictions = val_predictions + yp.to("cpu").numpy().tolist()
            val_scores = val_scores + torch.sigmoid(yh).to("cpu").numpy().tolist()
            val_directories = val_directories + list(bcs)

        pred_summary = pd.DataFrame({"label": val_labels, "prediction": val_predictions, "score": val_scores, "barcode": val_directories})
        pred_summary["correct"] = pred_summary["label"] == pred_summary["prediction"]

        conf_matrix = confusion_matrix(pred_summary["label"], pred_summary["prediction"])
        tp, tn, fp, fn = conf_matrix[1, 1], conf_matrix[0, 0], conf_matrix[0, 1], conf_matrix[1, 0]

        accuracy = accuracy_score(pred_summary["label"], pred_summary["prediction"])
        precision = precision_score(pred_summary["label"], pred_summary["prediction"])
        recall = recall_score(pred_summary["label"], pred_summary["prediction"])
        f1 = f1_score(pred_summary["label"], pred_summary["prediction"])
        specificity = tn / (tn + fp)

        val_loss = np.average(losses, weights=sizes)

    train_losses_epoch.append(train_loss)
    val_losses_epoch.append(val_loss)
    accuracies_epoch.append(accuracy)
    precision_epoch.append(precision)
    sensitivity_epoch.append(recall)
    specificity_epoch.append(specificity)
    f1_epoch.append(f1)
    
    epochs.append(epoch + 1)

    print(
        f'epoch {epoch + 1}/{num_epochs}, train_loss: {train_loss.item():.4f}, val_loss: {val_loss:.4f}, val_accu: {accuracy:.4f}, val_prec: {precision:.4f}, val_sens: {recall:.4f}, val_spec: {specificity:.4f}, val_f1: {f1:.4f}')
# Out:
# epoch 1/80, train_loss: 0.4239, val_loss: 0.3838, val_accu: 0.8293, val_prec: 0.7147, val_sens: 0.8645, val_spec: 0.8099, val_f1: 0.7825
# epoch 2/80, train_loss: 0.3628, val_loss: 0.3177, val_accu: 0.8843, val_prec: 0.8667, val_sens: 0.7968, val_spec: 0.9325, val_f1: 0.8303
# epoch 3/80, train_loss: 0.3157, val_loss: 0.2859, val_accu: 0.8900, val_prec: 0.8543, val_sens: 0.8323, val_spec: 0.9218, val_f1: 0.8431
# epoch 4/80, train_loss: 0.2862, val_loss: 0.2366, val_accu: 0.8958, val_prec: 0.9469, val_sens: 0.7484, val_spec: 0.9769, val_f1: 0.8360
# epoch 5/80, train_loss: 0.2639, val_loss: 0.2210, val_accu: 0.9015, val_prec: 0.9667, val_sens: 0.7484, val_spec: 0.9858, val_f1: 0.8436
# epoch 6/80, train_loss: 0.2457, val_loss: 0.2187, val_accu: 0.9026, val_prec: 0.9310, val_sens: 0.7839, val_spec: 0.9680, val_f1: 0.8511
# epoch 7/80, train_loss: 0.2316, val_loss: 0.1851, val_accu: 0.8935, val_prec: 0.9657, val_sens: 0.7258, val_spec: 0.9858, val_f1: 0.8287
# epoch 8/80, train_loss: 0.2196, val_loss: 0.1909, val_accu: 0.8992, val_prec: 0.9664, val_sens: 0.7419, val_spec: 0.9858, val_f1: 0.8394
# epoch 9/80, train_loss: 0.2073, val_loss: 0.1939, val_accu: 0.8992, val_prec: 0.9476, val_sens: 0.7581, val_spec: 0.9769, val_f1: 0.8423
# epoch 10/80, train_loss: 0.1996, val_loss: 0.1849, val_accu: 0.9015, val_prec: 0.9516, val_sens: 0.7613, val_spec: 0.9787, val_f1: 0.8459
# epoch 11/80, train_loss: 0.1914, val_loss: 0.1712, val_accu: 0.8969, val_prec: 0.9508, val_sens: 0.7484, val_spec: 0.9787, val_f1: 0.8375
# epoch 12/80, train_loss: 0.1840, val_loss: 0.1617, val_accu: 0.8946, val_prec: 0.9580, val_sens: 0.7355, val_spec: 0.9822, val_f1: 0.8321
# epoch 13/80, train_loss: 0.1743, val_loss: 0.1616, val_accu: 0.9015, val_prec: 0.9480, val_sens: 0.7645, val_spec: 0.9769, val_f1: 0.8464
# epoch 14/80, train_loss: 0.1705, val_loss: 0.1521, val_accu: 0.8969, val_prec: 0.9508, val_sens: 0.7484, val_spec: 0.9787, val_f1: 0.8375
# epoch 15/80, train_loss: 0.1610, val_loss: 0.1376, val_accu: 0.8946, val_prec: 0.9658, val_sens: 0.7290, val_spec: 0.9858, val_f1: 0.8309
# epoch 16/80, train_loss: 0.1571, val_loss: 0.1541, val_accu: 0.9072, val_prec: 0.9490, val_sens: 0.7806, val_spec: 0.9769, val_f1: 0.8566
# epoch 17/80, train_loss: 0.1507, val_loss: 0.1548, val_accu: 0.9141, val_prec: 0.9502, val_sens: 0.8000, val_spec: 0.9769, val_f1: 0.8687
# epoch 18/80, train_loss: 0.1430, val_loss: 0.1239, val_accu: 0.8969, val_prec: 0.9701, val_sens: 0.7323, val_spec: 0.9876, val_f1: 0.8346
# epoch 19/80, train_loss: 0.1364, val_loss: 0.1319, val_accu: 0.9026, val_prec: 0.9630, val_sens: 0.7548, val_spec: 0.9840, val_f1: 0.8463
# epoch 20/80, train_loss: 0.1312, val_loss: 0.1357, val_accu: 0.9084, val_prec: 0.9563, val_sens: 0.7774, val_spec: 0.9805, val_f1: 0.8577
# epoch 21/80, train_loss: 0.1269, val_loss: 0.1171, val_accu: 0.8992, val_prec: 0.9664, val_sens: 0.7419, val_spec: 0.9858, val_f1: 0.8394
# epoch 22/80, train_loss: 0.1224, val_loss: 0.1210, val_accu: 0.9049, val_prec: 0.9633, val_sens: 0.7613, val_spec: 0.9840, val_f1: 0.8505
# epoch 23/80, train_loss: 0.1172, val_loss: 0.1105, val_accu: 0.8992, val_prec: 0.9784, val_sens: 0.7323, val_spec: 0.9911, val_f1: 0.8376
# epoch 24/80, train_loss: 0.1133, val_loss: 0.0955, val_accu: 0.8958, val_prec: 0.9782, val_sens: 0.7226, val_spec: 0.9911, val_f1: 0.8312
# epoch 25/80, train_loss: 0.1094, val_loss: 0.1120, val_accu: 0.9015, val_prec: 0.9667, val_sens: 0.7484, val_spec: 0.9858, val_f1: 0.8436
# epoch 26/80, train_loss: 0.1036, val_loss: 0.1020, val_accu: 0.9038, val_prec: 0.9788, val_sens: 0.7452, val_spec: 0.9911, val_f1: 0.8462
# epoch 27/80, train_loss: 0.0995, val_loss: 0.0960, val_accu: 0.9026, val_prec: 0.9787, val_sens: 0.7419, val_spec: 0.9911, val_f1: 0.8440
# epoch 28/80, train_loss: 0.0953, val_loss: 0.1002, val_accu: 0.9084, val_prec: 0.9675, val_sens: 0.7677, val_spec: 0.9858, val_f1: 0.8561
# epoch 29/80, train_loss: 0.0937, val_loss: 0.0901, val_accu: 0.9038, val_prec: 0.9788, val_sens: 0.7452, val_spec: 0.9911, val_f1: 0.8462
# epoch 30/80, train_loss: 0.0909, val_loss: 0.0769, val_accu: 0.8992, val_prec: 0.9784, val_sens: 0.7323, val_spec: 0.9911, val_f1: 0.8376
# epoch 31/80, train_loss: 0.0894, val_loss: 0.0971, val_accu: 0.9095, val_prec: 0.9753, val_sens: 0.7645, val_spec: 0.9893, val_f1: 0.8571
# epoch 32/80, train_loss: 0.0850, val_loss: 0.0741, val_accu: 0.8992, val_prec: 0.9912, val_sens: 0.7226, val_spec: 0.9964, val_f1: 0.8358
# epoch 33/80, train_loss: 0.0808, val_loss: 0.0912, val_accu: 0.9095, val_prec: 0.9753, val_sens: 0.7645, val_spec: 0.9893, val_f1: 0.8571
# epoch 34/80, train_loss: 0.0803, val_loss: 0.0837, val_accu: 0.9049, val_prec: 0.9749, val_sens: 0.7516, val_spec: 0.9893, val_f1: 0.8488
# epoch 35/80, train_loss: 0.0751, val_loss: 0.0735, val_accu: 0.9038, val_prec: 0.9871, val_sens: 0.7387, val_spec: 0.9947, val_f1: 0.8450
# epoch 36/80, train_loss: 0.0736, val_loss: 0.0781, val_accu: 0.9095, val_prec: 0.9753, val_sens: 0.7645, val_spec: 0.9893, val_f1: 0.8571
# epoch 37/80, train_loss: 0.0720, val_loss: 0.0775, val_accu: 0.9095, val_prec: 0.9753, val_sens: 0.7645, val_spec: 0.9893, val_f1: 0.8571
# epoch 38/80, train_loss: 0.0706, val_loss: 0.0779, val_accu: 0.9107, val_prec: 0.9754, val_sens: 0.7677, val_spec: 0.9893, val_f1: 0.8592
# epoch 39/80, train_loss: 0.0658, val_loss: 0.0657, val_accu: 0.9049, val_prec: 0.9913, val_sens: 0.7387, val_spec: 0.9964, val_f1: 0.8466
# epoch 40/80, train_loss: 0.0647, val_loss: 0.0770, val_accu: 0.9107, val_prec: 0.9754, val_sens: 0.7677, val_spec: 0.9893, val_f1: 0.8592
# epoch 41/80, train_loss: 0.0616, val_loss: 0.0676, val_accu: 0.9061, val_prec: 0.9914, val_sens: 0.7419, val_spec: 0.9964, val_f1: 0.8487
# epoch 42/80, train_loss: 0.0649, val_loss: 0.0560, val_accu: 0.8935, val_prec: 0.9910, val_sens: 0.7065, val_spec: 0.9964, val_f1: 0.8249
# epoch 43/80, train_loss: 0.0581, val_loss: 0.0625, val_accu: 0.9072, val_prec: 0.9872, val_sens: 0.7484, val_spec: 0.9947, val_f1: 0.8514
# epoch 44/80, train_loss: 0.0565, val_loss: 0.0603, val_accu: 0.9026, val_prec: 0.9913, val_sens: 0.7323, val_spec: 0.9964, val_f1: 0.8423
# epoch 45/80, train_loss: 0.0542, val_loss: 0.0515, val_accu: 0.8946, val_prec: 0.9910, val_sens: 0.7097, val_spec: 0.9964, val_f1: 0.8271
# epoch 46/80, train_loss: 0.0541, val_loss: 0.0506, val_accu: 0.8889, val_prec: 0.9908, val_sens: 0.6935, val_spec: 0.9964, val_f1: 0.8159
# epoch 47/80, train_loss: 0.0523, val_loss: 0.0557, val_accu: 0.9072, val_prec: 0.9914, val_sens: 0.7452, val_spec: 0.9964, val_f1: 0.8508
# epoch 48/80, train_loss: 0.0513, val_loss: 0.0596, val_accu: 0.9107, val_prec: 0.9874, val_sens: 0.7581, val_spec: 0.9947, val_f1: 0.8577
# epoch 49/80, train_loss: 0.0507, val_loss: 0.0502, val_accu: 0.8981, val_prec: 0.9911, val_sens: 0.7194, val_spec: 0.9964, val_f1: 0.8336
# epoch 50/80, train_loss: 0.0492, val_loss: 0.0532, val_accu: 0.8981, val_prec: 0.9911, val_sens: 0.7194, val_spec: 0.9964, val_f1: 0.8336
# epoch 51/80, train_loss: 0.0479, val_loss: 0.0459, val_accu: 0.8992, val_prec: 0.9912, val_sens: 0.7226, val_spec: 0.9964, val_f1: 0.8358
# epoch 52/80, train_loss: 0.0457, val_loss: 0.0469, val_accu: 0.8992, val_prec: 0.9912, val_sens: 0.7226, val_spec: 0.9964, val_f1: 0.8358
# epoch 53/80, train_loss: 0.0464, val_loss: 0.0469, val_accu: 0.9015, val_prec: 0.9912, val_sens: 0.7290, val_spec: 0.9964, val_f1: 0.8401
# epoch 54/80, train_loss: 0.0446, val_loss: 0.0460, val_accu: 0.8958, val_prec: 0.9910, val_sens: 0.7129, val_spec: 0.9964, val_f1: 0.8293
# epoch 55/80, train_loss: 0.0428, val_loss: 0.0498, val_accu: 0.9084, val_prec: 0.9915, val_sens: 0.7484, val_spec: 0.9964, val_f1: 0.8529
# epoch 56/80, train_loss: 0.0420, val_loss: 0.0477, val_accu: 0.9061, val_prec: 0.9914, val_sens: 0.7419, val_spec: 0.9964, val_f1: 0.8487
# epoch 57/80, train_loss: 0.0421, val_loss: 0.0426, val_accu: 0.8992, val_prec: 0.9912, val_sens: 0.7226, val_spec: 0.9964, val_f1: 0.8358
# epoch 58/80, train_loss: 0.0402, val_loss: 0.0467, val_accu: 0.9049, val_prec: 0.9913, val_sens: 0.7387, val_spec: 0.9964, val_f1: 0.8466
# epoch 59/80, train_loss: 0.0395, val_loss: 0.0381, val_accu: 0.8912, val_prec: 0.9909, val_sens: 0.7000, val_spec: 0.9964, val_f1: 0.8204
# epoch 60/80, train_loss: 0.0379, val_loss: 0.0450, val_accu: 0.9038, val_prec: 0.9913, val_sens: 0.7355, val_spec: 0.9964, val_f1: 0.8444
# epoch 61/80, train_loss: 0.0389, val_loss: 0.0394, val_accu: 0.8900, val_prec: 0.9908, val_sens: 0.6968, val_spec: 0.9964, val_f1: 0.8182
# epoch 62/80, train_loss: 0.0377, val_loss: 0.0371, val_accu: 0.8843, val_prec: 0.9906, val_sens: 0.6806, val_spec: 0.9964, val_f1: 0.8069
# epoch 63/80, train_loss: 0.0381, val_loss: 0.0417, val_accu: 0.9003, val_prec: 0.9912, val_sens: 0.7258, val_spec: 0.9964, val_f1: 0.8380
# epoch 64/80, train_loss: 0.0358, val_loss: 0.0359, val_accu: 0.8900, val_prec: 0.9908, val_sens: 0.6968, val_spec: 0.9964, val_f1: 0.8182
# epoch 65/80, train_loss: 0.0342, val_loss: 0.0324, val_accu: 0.8843, val_prec: 0.9906, val_sens: 0.6806, val_spec: 0.9964, val_f1: 0.8069
# epoch 66/80, train_loss: 0.0318, val_loss: 0.0289, val_accu: 0.8889, val_prec: 0.9908, val_sens: 0.6935, val_spec: 0.9964, val_f1: 0.8159
# epoch 67/80, train_loss: 0.0292, val_loss: 0.0272, val_accu: 0.8751, val_prec: 0.9902, val_sens: 0.6548, val_spec: 0.9964, val_f1: 0.7883
# epoch 68/80, train_loss: 0.0275, val_loss: 0.0264, val_accu: 0.8889, val_prec: 0.9953, val_sens: 0.6903, val_spec: 0.9982, val_f1: 0.8152
# epoch 69/80, train_loss: 0.0268, val_loss: 0.0254, val_accu: 0.8843, val_prec: 0.9906, val_sens: 0.6806, val_spec: 0.9964, val_f1: 0.8069
# epoch 70/80, train_loss: 0.0249, val_loss: 0.0253, val_accu: 0.8958, val_prec: 0.9910, val_sens: 0.7129, val_spec: 0.9964, val_f1: 0.8293
# epoch 71/80, train_loss: 0.0247, val_loss: 0.0239, val_accu: 0.8923, val_prec: 0.9954, val_sens: 0.7000, val_spec: 0.9982, val_f1: 0.8220
# epoch 72/80, train_loss: 0.0237, val_loss: 0.0241, val_accu: 0.9049, val_prec: 0.9913, val_sens: 0.7387, val_spec: 0.9964, val_f1: 0.8466
# epoch 73/80, train_loss: 0.0245, val_loss: 0.0226, val_accu: 0.9061, val_prec: 0.9957, val_sens: 0.7387, val_spec: 0.9982, val_f1: 0.8481
# epoch 74/80, train_loss: 0.0230, val_loss: 0.0223, val_accu: 0.8900, val_prec: 0.9954, val_sens: 0.6935, val_spec: 0.9982, val_f1: 0.8175
# epoch 75/80, train_loss: 0.0221, val_loss: 0.0221, val_accu: 0.8981, val_prec: 0.9955, val_sens: 0.7161, val_spec: 0.9982, val_f1: 0.8330
# epoch 76/80, train_loss: 0.0228, val_loss: 0.0211, val_accu: 0.8923, val_prec: 0.9954, val_sens: 0.7000, val_spec: 0.9982, val_f1: 0.8220
# epoch 77/80, train_loss: 0.0228, val_loss: 0.0206, val_accu: 0.9003, val_prec: 0.9956, val_sens: 0.7226, val_spec: 0.9982, val_f1: 0.8374
# epoch 78/80, train_loss: 0.0226, val_loss: 0.0207, val_accu: 0.8992, val_prec: 0.9955, val_sens: 0.7194, val_spec: 0.9982, val_f1: 0.8352
# epoch 79/80, train_loss: 0.0211, val_loss: 0.0210, val_accu: 0.8969, val_prec: 0.9955, val_sens: 0.7129, val_spec: 0.9982, val_f1: 0.8308
# epoch 80/80, train_loss: 0.0205, val_loss: 0.0201, val_accu: 0.8992, val_prec: 0.9955, val_sens: 0.7194, val_spec: 0.9982, val_f1: 0.8352

# %%
plt.figure(figsize=(5, 2))
plt.plot(epochs, train_losses_epoch, label='train_loss')
plt.plot(epochs, val_losses_epoch, label='val_loss')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(5, 2))
plt.plot(epochs, train_losses_epoch, label='train_loss')
plt.plot(epochs, val_losses_epoch, label='val_loss')
plt.legend()
plt.ylim(0, 0.05)
plt.grid(True)
plt.show()

plt.figure(figsize=(5, 2))
plt.plot(epochs, accuracies_epoch, label='accuracy')
plt.plot(epochs, precision_epoch, label='precision')
plt.plot(epochs, sensitivity_epoch, label='sensitivity')
plt.plot(epochs, specificity_epoch, label='specificity')
plt.plot(epochs, f1_epoch, label='f1')
plt.legend()
plt.grid(True)
plt.show()

fpr, tpr, thresholds = roc_curve(pred_summary["label"], pred_summary["score"])
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.4f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

print(pd.DataFrame(conf_matrix, index=["TN", "TP"], columns=["PN", "PP"]))
# Out:
#      PN   PP
# TN  562    1
# TP   87  223

# %% [markdown]
# ### Test model

# %%
#model.load_state_dict(torch.load("model_nov29.pt"))
#model.to("mps")

# %%
matrix_test = read_mtx("data/raw/LC500/LC500_ACTAGGTGTTACCCAA/matrix.mtx", chr_index)
add_test = read_add("data/raw/LC500/LC500_ACTAGGTGTTACCCAA/1000000.CNV.bedGraph", chr_index)
#LC499/LC499_TTATGTCAGAGGAACA
#LC499/LC499_AACGGGAGTCCCGAGT
#LC675/LC675_AGCGTGCAGAGAGTAG
#LC500/LC500_AAACGAAGTTAGCTCA

plt.figure(figsize=(40, 40))
plot = sns.heatmap(matrix_test > 0, cbar=False)

coord = np.where(chr_index["loc"] == "chr7_55000000")[0][0]
plot.axvline(x=coord, color='red', linestyle='--', linewidth=1)
plt.show()

# %%
def slide(matrix, add_in,  window_0, window_1):
    half_window_0 = int((window_0 - 1) / 2)
    half_window_1 = int((window_1 - 1) / 2)

    centers = []
    tensors = []
    adds = []

    for i in range(matrix.shape[0] - window_1 + 1):
        center = i + half_window_1
        lower = center - half_window_0
        upper = center + half_window_0 + 1

        tensors.append(matrix[lower:upper, :])
        add = torch.from_numpy(add_in[lower:upper]["add"].to_numpy(dtype=np.float32))
        adds.append(add)
        centers.append(center)
        
    test_tensor = torch.stack(tensors, dim=0)
    adds = torch.stack(adds, dim=0)
    centers = np.array(centers)
    
    return test_tensor, centers, adds

# %%
test_tensor, centers, adds = slide(torch.from_numpy(matrix_test), add_test, window_0, window_1)

model.eval()
with torch.no_grad():
    test_tensor = test_tensor.unsqueeze(1).float().to("mps")
    adds = adds.float().to("mps")

    test_pred = torch.sigmoid(model(test_tensor, centers, adds).to("cpu"))

test_predictions = pd.DataFrame({"coord": centers, "prediction": test_pred})

test_predictions = pd.merge(test_predictions, chr_index, left_on="coord", right_on="index", how="left").drop("index",
                                                                                                             axis=1)

# %%
plt.figure(figsize=(20, 5))

plt.scatter(test_predictions['coord'], test_predictions['prediction'])

top_indices = test_predictions['prediction'].argsort()[-3:]

texts = []
for i in top_indices:
    x_value = test_predictions['loc'][i]
    texts.append(plt.text(i, test_predictions['prediction'][i], f'{x_value}', ha='center', va='bottom'))

adjust_text(texts)

plt.ylim(-0.05, 1.05)
plt.show()

# %%
#torch.save(model.state_dict(), "model_nov29.pt")

# %% [markdown]
# ### Comparison with Linear Model

# %%
lm_val_pred_1 = pd.read_csv("data/lm_summarized/prediction_499500.csv", header=None)
lm_val_pred_1.columns = ["cnv", "ratio", "gini", "label","score"]

#lm_val_pred_2 = pd.read_csv("data/lm_summarized/prediction_all_676677.csv", header=None)
#lm_val_pred_2.columns = ["cnv", "ratio", "gini", "label","score"]

#lm_val_pred_3 = pd.read_csv("data/lm_summarized/prediction_all_mixed.csv", header=None)
#lm_val_pred_3.columns = ["cnv", "ratio", "gini", "label","score"]

# %%
sizes = []

val_labels = []
val_predictions = []
val_scores = []
val_directories = []

model.eval()
with torch.no_grad():
    for x2, y0, bcs, coord, add in val_dataloader:
        x2 = x2.float().to("mps")
        y0 = y0.float().to("mps")
        add = add.float().to("mps")

        yh = model(x2, coord, add)

        yp = (torch.sigmoid(yh) > prob_threshold).int()

        accu = torch.sum((yp == y0).float()) / len(y0)

        sizes.append(len(y0))

        val_labels = val_labels + y0.int().to("cpu").numpy().tolist()
        val_predictions = val_predictions + yp.to("cpu").numpy().tolist()
        val_scores = val_scores + torch.sigmoid(yh).to("cpu").numpy().tolist()
        val_directories = val_directories + list(bcs)

# %%
pred_summary = pd.DataFrame({"label": val_labels, "prediction": val_predictions, "score": val_scores, "barcode": val_directories})
pred_summary["correct"] = pred_summary["label"] == pred_summary["prediction"]

conf_matrix = confusion_matrix(pred_summary["label"], pred_summary["prediction"])
tp, tn, fp, fn = conf_matrix[1, 1], conf_matrix[0, 0], conf_matrix[0, 1], conf_matrix[1, 0]

accuracy = accuracy_score(pred_summary["label"], pred_summary["prediction"])
precision = precision_score(pred_summary["label"], pred_summary["prediction"])
recall = recall_score(pred_summary["label"], pred_summary["prediction"])
f1 = f1_score(pred_summary["label"], pred_summary["prediction"])
specificity = tn / (tn + fp)

# %%
fpr_lm_1, tpr_lm_1, _ = roc_curve(lm_val_pred_1["label"], lm_val_pred_1["score"])
roc_auc_lm_1 = auc(fpr_lm_1, tpr_lm_1)

#fpr_lm_2, tpr_lm_2, _ = roc_curve(lm_val_pred_2["label"], lm_val_pred_2["score"])
#roc_auc_lm_2 = auc(fpr_lm_2, tpr_lm_2)

#fpr_lm_3, tpr_lm_3, _ = roc_curve(lm_val_pred_3["label"], lm_val_pred_3["score"])
#roc_auc_lm_3 = auc(fpr_lm_3, tpr_lm_3)

fpr_cnn, tpr_cnn, _ = roc_curve(pred_summary["label"], pred_summary["score"])
roc_auc_cnn = auc(fpr_cnn, tpr_cnn)

# %%
plt.figure()
plt.plot(fpr_lm_1, tpr_lm_1, color='red', lw=1, label='Linear Model 1 (area = {:.4f})'.format(roc_auc_lm_1))
#plt.plot(fpr_lm_2, tpr_lm_2, color='blue', lw=1, label='Linear Model 2 (area = {:.4f})'.format(roc_auc_lm_2))
#plt.plot(fpr_lm_3, tpr_lm_3, color='green', lw=1, label='Linear Model M (area = {:.4f})'.format(roc_auc_lm_3))
plt.plot(fpr_cnn, tpr_cnn, color='orange', lw=1, label='Deep Model (area = {:.4f})'.format(roc_auc_cnn))
plt.plot([0, 1], [0, 1], color='grey', lw=1, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %%
pred_summary.iloc[np.where(pred_summary["correct"] == False)[0], :]
# Out:
#      label  prediction     score                 barcode  correct
# 4        1           0  0.224960  LC499_AACAAAGTCCATGACA    False
# 8        1           0  0.434184  LC499_AACTTGGGTACATGGG    False
# 20       1           0  0.487825  LC499_ACAGGCCAGCATTGGG    False
# 22       1           0  0.384244  LC499_ACCCAAACACGTACAT    False
# 26       1           0  0.458097  LC499_ACCGCAGTCACAACAC    False
# ..     ...         ...       ...                     ...      ...
# 295      1           0  0.313145  LC499_TTGCACCTCTGGCGCA    False
# 302      1           0  0.047643  LC499_TTGCTTAAGTAGCAAT    False
# 304      1           0  0.006022  LC499_TTGTTCATCTCGACCT    False
# 308      1           0  0.396121  LC499_TTTGGCCGTTGTGACT    False
# 375      0           1  0.734868  LC500_ACTAGGTGTTACCCAA    False
#
# [88 rows x 5 columns]

# %%
#pred_summary["barcode"].to_csv("data/processed/barcode_val_499500.txt", index=False, header=False)

# %% [markdown]
# ### Generalize to other datasets

# %%
#model.load_state_dict(torch.load("model_nov29.pt"))
#model.to("mps")

# %%
lm_test_pred_1 = pd.read_csv("data/lm_summarized/prediction_676677.csv", header=None)
lm_test_pred_1.columns = ["cnv", "ratio", "gini", "label","score"]

#lm_test_pred_2 = pd.read_csv("data/lm_summarized/prediction_729730_676677.csv", header=None)
#lm_test_pred_2.columns = ["cnv", "ratio", "gini", "label","score"]

#lm_test_pred_3 = pd.read_csv("data/lm_summarized/prediction_729730_mixed.csv", header=None)
#lm_test_pred_3.columns = ["cnv", "ratio", "gini", "label","score"]

# %%
sizes = []

val_labels = []
val_predictions = []
val_scores = []
val_directories = []

model.eval()
with torch.no_grad():
    for x2, y0, bcs, coord, add in test_dataloader1:
        x2 = x2.float().to("mps")
        y0 = y0.float().to("mps")
        add = add.float().to("mps")

        yh = model(x2, coord, add)

        yp = (torch.sigmoid(yh) > prob_threshold).int()

        accu = torch.sum((yp == y0).float()) / len(y0)

        sizes.append(len(y0))

        val_labels = val_labels + y0.int().to("cpu").numpy().tolist()
        val_predictions = val_predictions + yp.to("cpu").numpy().tolist()
        val_scores = val_scores + torch.sigmoid(yh).to("cpu").numpy().tolist()
        val_directories = val_directories + list(bcs)

# %%
pred_summary = pd.DataFrame(
    {"label": val_labels, "prediction": val_predictions, "score": val_scores, "barcode": val_directories})
pred_summary["correct"] = pred_summary["label"] == pred_summary["prediction"]

conf_matrix = confusion_matrix(pred_summary["label"], pred_summary["prediction"])
tp, tn, fp, fn = conf_matrix[1, 1], conf_matrix[0, 0], conf_matrix[0, 1], conf_matrix[1, 0]

accuracy = accuracy_score(pred_summary["label"], pred_summary["prediction"])
precision = precision_score(pred_summary["label"], pred_summary["prediction"])
recall = recall_score(pred_summary["label"], pred_summary["prediction"])
f1 = f1_score(pred_summary["label"], pred_summary["prediction"])
specificity = tn / (tn + fp)

# %%
fpr_lm_1, tpr_lm_1, _ = roc_curve(lm_test_pred_1["label"], lm_test_pred_1["score"])
roc_auc_lm_1 = auc(fpr_lm_1, tpr_lm_1)

#fpr_lm_2, tpr_lm_2, _ = roc_curve(lm_test_pred_2["label"], lm_test_pred_2["score"])
#roc_auc_lm_2 = auc(fpr_lm_2, tpr_lm_2)

#fpr_lm_3, tpr_lm_3, _ = roc_curve(lm_test_pred_3["label"], lm_test_pred_3["score"])
#roc_auc_lm_3 = auc(fpr_lm_3, tpr_lm_3)

fpr_cnn, tpr_cnn, _ = roc_curve(pred_summary["label"], pred_summary["score"])
roc_auc_cnn = auc(fpr_cnn, tpr_cnn)

# %%
plt.figure()
plt.plot(fpr_lm_1, tpr_lm_1, color='red', lw=1, label='Linear Model 1 (area = {:.4f})'.format(roc_auc_lm_1))
#plt.plot(fpr_lm_2, tpr_lm_2, color='blue', lw=1, label='Linear Model 2 (area = {:.4f})'.format(roc_auc_lm_2))
#plt.plot(fpr_lm_3, tpr_lm_3, color='green', lw=1, label='Linear Model M (area = {:.4f})'.format(roc_auc_lm_3))
plt.plot(fpr_cnn, tpr_cnn, color='orange', lw=1, label='Deep Model (area = {:.4f})'.format(roc_auc_cnn))
plt.plot([0, 1], [0, 1], color='grey', lw=1, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()
